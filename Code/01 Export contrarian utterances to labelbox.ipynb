# %%
import pandas as pd
import re
from pdfminer.high_level import extract_text
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_json("../Data/testimonies.json")

# %%
# Explode the testimonies 
df = df.explode("utterances")#.reset_index()

# %%
# Create utterance id
df['id_U'] = df.groupby(['id_H', 'id_T']).cumcount() + 1
# Count utterance length 
df["word_count"] = df.utterances.apply(lambda x: len(str(x).split()))
# Create unique utterance id
df['global_key'] = df.id_H.astype(str) + "_T_" + df.id_T.astype(str) + "__U_" + df.id_U.astype(str) + "_"

# %%
df.head()
# Out:
#    congress chamber                                          committee  \
# 0       108  Senate  Committee on Commerce, Science, and Transporta...
# 0       108  Senate  Committee on Commerce, Science, and Transporta...
# 0       108  Senate  Committee on Commerce, Science, and Transporta...
# 0       108  Senate  Committee on Commerce, Science, and Transporta...
# 0       108  Senate  Committee on Commerce, Science, and Transporta...
#
#                          committee_short  year       date  \
# 0  Commerce, Science, and Transportation  2004 2004-05-06
# 0  Commerce, Science, and Transportation  2004 2004-05-06
# 0  Commerce, Science, and Transportation  2004 2004-05-06
# 0  Commerce, Science, and Transportation  2004 2004-05-06
# 0  Commerce, Science, and Transportation  2004 2004-05-06
#
#                                                title          id_H  \
# 0  The Impacts of Climate Change and States' Actions  108shrg82493
# 0  The Impacts of Climate Change and States' Actions  108shrg82493
# 0  The Impacts of Climate Change and States' Actions  108shrg82493
# 0  The Impacts of Climate Change and States' Actions  108shrg82493
# 0  The Impacts of Climate Change and States' Actions  108shrg82493
#
#                                              witness witness_name  ...  \
# 0  Colburn, Kenneth A., Executive Director, North...      Colburn  ...
# 0  Colburn, Kenneth A., Executive Director, North...      Colburn  ...
# 0  Colburn, Kenneth A., Executive Director, North...      Colburn  ...
# 0  Colburn, Kenneth A., Executive Director, North...      Colburn  ...
# 0  Colburn, Kenneth A., Executive Director, North...      Colburn  ...
#
#             subcategory state_research contrarian_organisation     contrarian  \
# 0  Government Officials              0                    None  Other witness
# 0  Government Officials              0                    None  Other witness
# 0  Government Officials              0                    None  Other witness
# 0  Government Officials              0                    None  Other witness
# 0  Government Officials              0                    None  Other witness
#
#        denialist                                         utterances id_T id_U  \
# 0  Other witness  Thank you, Mr. Chairman. It's a delight to be ...    1    1
# 0  Other witness  My name's Ken Colburn. I'm the Executive Direc...    1    2
# 0  Other witness  The biggest concern I have, Senator, is stayin...    1    3
# 0  Other witness  This week is a good example. On Monday, the no...    1    4
# 0  Other witness  Senator, I'm not sure if California has those ...    1    5
#
#   word_count              global_key
# 0         10  108shrg82493_T_1__U_1_
# 0         59  108shrg82493_T_1__U_2_
# 0         42  108shrg82493_T_1__U_3_
# 0         51  108shrg82493_T_1__U_4_
# 0         16  108shrg82493_T_1__U_5_
#
# [5 rows x 24 columns]

# %%
# Save the data at utterance level
df.reset_index(inplace=True, drop =True)
df.to_json("../Data/utterances.json")

# %%
# Subset contrarian utterances with at least 10 words
con = df[df.contrarian == "Contrarian"]
con = con[con.word_count >=10]
con.reset_index(inplace=True, drop =True)
con.head(3)
# Out:
#    congress chamber                         committee      committee_short  \
# 0       108   House  Committee on Energy and Commerce  Energy and Commerce
# 1       108   House  Committee on Energy and Commerce  Energy and Commerce
# 2       108   House  Committee on Energy and Commerce  Energy and Commerce
#
#    year       date                                              title  \
# 0  2003 2003-07-08  The Clear Skies Initiative: A Multipollutant A...
# 1  2003 2003-07-08  The Clear Skies Initiative: A Multipollutant A...
# 2  2003 2003-07-08  The Clear Skies Initiative: A Multipollutant A...
#
#            id_H                                            witness  \
# 0  108hhrg88427  Holmstead, Hon. Jeffrey, Assistant Administrat...
# 1  108hhrg88427  Holmstead, Hon. Jeffrey, Assistant Administrat...
# 2  108hhrg88427  Holmstead, Hon. Jeffrey, Assistant Administrat...
#
#   witness_name  ...           subcategory state_research  \
# 0    Holmstead  ...  Government Officials              0
# 1    Holmstead  ...  Government Officials              0
# 2    Holmstead  ...  Government Officials              0
#
#   contrarian_organisation  contrarian         denialist  \
# 0                    None  Contrarian  Other contrarian
# 1                    None  Contrarian  Other contrarian
# 2                    None  Contrarian  Other contrarian
#
#                                           utterances id_T id_U word_count  \
# 0  It really is an honor to be here today and to ...    1    2         53
# 1  I have been looking forward to this opportunit...    1    3         81
# 2  As a number of you have mentioned, the air in ...    1    4         76
#
#                global_key
# 0  108hhrg88427_T_1__U_2_
# 1  108hhrg88427_T_1__U_3_
# 2  108hhrg88427_T_1__U_4_
#
# [3 rows x 24 columns]

# %%
# Prepare contrarian utterances for export to labelbox
con["value"] = "tag_string"
con = con[['utterances', 'global_key']]
con = con.rename(columns={"utterances": "row_data"})
con["media_type"] = "TEXT"
con.reset_index(inplace=True, drop=True)
con.head()
# Out:
#                                             row_data              global_key  \
# 0  It really is an honor to be here today and to ...  108hhrg88427_T_1__U_2_
# 1  I have been looking forward to this opportunit...  108hhrg88427_T_1__U_3_
# 2  As a number of you have mentioned, the air in ...  108hhrg88427_T_1__U_4_
# 3  Over the last 30 years, as we have implemented...  108hhrg88427_T_1__U_5_
# 4  A lot of you have mentioned concern about natu...  108hhrg88427_T_1__U_6_
#
#   media_type
# 0       TEXT
# 1       TEXT
# 2       TEXT
# 3       TEXT
# 4       TEXT

# %%
label_dicts = con.to_dict('records')
label_dicts[0:2]
# Out:
# [{'row_data': 'It really is an honor to be here today and to appear in front of you again. I had planned to begin by singing a rousing rendition of Happy Birthday to Mr. Dingell. But now that Chairman Tauzin has already recognized this day, I think I will defer in all of our interests.',
#   'global_key': '108hhrg88427_T_1__U_2_',
#   'media_type': 'TEXT'},
#  {'row_data': "I have been looking forward to this opportunity for quite some time. And at your invitation, I am going to depart from custom a little bit, and rather than reading a statement, what I would like to do is just give a relatively brief presentation and go through some slides in the hope that we can collectively understand some of these issues a little bit better. And I do hope, in particular, that I can begin to overcome Mr. Dingell's skepticism.",
#   'global_key': '108hhrg88427_T_1__U_3_',
#   'media_type': 'TEXT'}]

# %%
# from labelbox import Client

# client = Client(api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..Cm4rJlDd2B53BXtcXpLP0DvWSjmeWr8GdZU9RV5NEPQ")

# dataset = client.create_dataset(name="Cap-and-trade contrarian testimonies")

# task = dataset.create_data_rows(label_dicts)
# task.wait_till_done()
# print(task.errors)
